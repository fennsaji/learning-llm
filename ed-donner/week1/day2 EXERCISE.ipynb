# %% [markdown]
# # Welcome to your first assignment!
#
# Instructions are below. Please give this a try, and look in the solutions folder if you get stuck (or feel free to ask me!)

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Just before we get to the assignment --</h2>
#             <span style="color:#f71;">I thought I'd take a second to point you at this page of useful resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # HOMEWORK EXERCISE ASSIGNMENT
#
# Upgrade the day 1 project to summarize a webpage to use an Open Source model running locally via Ollama rather than OpenAI
#
# You'll be able to use this technique for all subsequent projects if you'd prefer not to use paid APIs.
#
# **Benefits:**
# 1. No API charges - open-source
# 2. Data doesn't leave your box
#
# **Disadvantages:**
# 1. Significantly less power than Frontier Model
#
# ## Recap on installation of Ollama
#
# Simply visit [ollama.com](https://ollama.com) and install!
#
# Once complete, the ollama server should already be running locally.
# If you visit:
# [http://localhost:11434/](http://localhost:11434/)
#
# You should see the message `Ollama is running`.
#
# If not, bring up a new Terminal (Mac) or Powershell (Windows) and enter `ollama serve`
# And in another Terminal (Mac) or Powershell (Windows), enter `ollama pull llama3.2`
# Then try [http://localhost:11434/](http://localhost:11434/) again.
#
# If Ollama is slow on your machine, try using `llama3.2:1b` as an alternative. Run `ollama pull llama3.2:1b` from a Terminal or Powershell, and change the code below from `MODEL = "llama3.2"` to `MODEL = "llama3.2:1b"`

# %%
# imports

import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
# Constants

OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "gemma3:4b"

# %%
# Create a messages list using the same format that we used for OpenAI

messages = [
    {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }

# %%
# Let's just make sure the model is loaded

# !ollama pull gemma3:4b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# verifying sha256 digest
# writing manifest
# success

# %%
# If this doesn't work for any reason, try the 2 versions in the following cells
# And double check the instructions in the 'Recap on installation of Ollama' at the top of this lab
# And if none of that works - contact me!

response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# Okay, let's break down the diverse business applications of Generative AI – it’s exploding right now! Here’s a categorized overview, with examples and levels of impact:
#
# **1. Content Creation & Marketing:** This is arguably the most prominent area right now.
#
# * **Copywriting & Marketing Materials:**
#     * **Generating Ad Copy:** Tools like Jasper.ai, Copy.ai, and Rytr can generate variations of ad copy for different platforms (Google Ads, Facebook, LinkedIn) in seconds, drastically speeding up campaign creation.
#     * **Blog Posts & Articles:**  AI can draft initial drafts of blog posts, articles, and website content, freeing up content marketers to refine and add depth. (e.g., using ChatGPT to create a blog post outline and then have it generate sections).
#     * **Product Descriptions:** Creating compelling product descriptions for e-commerce sites – easily generating multiple versions to A/B test.
#     * **Social Media Content:**  Generating captions, hashtag suggestions, and even entire social media posts based on brand guidelines and desired tone.
# * **Visual Content:**
#     * **Image Generation:** Tools like DALL-E 2, Midjourney, and Stable Diffusion can create original images from text prompts. This is huge for:
#         * **Marketing Materials:** Generating unique illustrations and visuals for ads, websites, and social media.
#         * **Product Mockups:**  Creating realistic product mockups for presentations and marketing.
#         * **Concept Art & Design Exploration:** Quickly visualizing design concepts.
#     * **Video Generation:** Emerging tools are starting to generate short videos from text or images. (e.g., Synthesia, RunwayML)
#
# **2. Customer Service & Support:**
#
# * **Chatbots & Virtual Assistants:** Generative AI takes chatbots to the next level. They can:
#     * **Handle Complex Queries:** Go beyond simple FAQ responses and understand nuanced questions.
#     * **Personalized Interactions:** Tailor responses based on customer history and preferences.
#     * **Generate Troubleshooting Steps:**  Provide customized solutions for technical issues.
# * **Email Automation:** Drafting responses to common customer inquiries, freeing up support teams.
#
# **3. Product Development & Design:**
#
# * **Brainstorming & Idea Generation:** AI can rapidly generate new product ideas, features, and marketing angles.
# * **Code Generation:** Tools like GitHub Copilot leverage generative AI to assist developers by:
#     * **Suggesting Code:** Autocompleting code snippets and entire functions.
#     * **Translating Between Languages:**  Converting code between different programming languages.
#     * **Generating Unit Tests:**  Creating automated tests to ensure code quality.
# * **Design Prototyping:**  AI can assist in generating initial design mockups and prototypes, accelerating the design process.
# * **Simulations & Modeling:**  Generative AI can create realistic simulations for testing product performance under various conditions.
#
# **4. Data Analysis & Insights:**
#
# * **Data Summarization:**  AI can quickly summarize large datasets, extracting key insights for business leaders.
# * **Report Generation:**  Automating the creation of reports, saving analysts time and effort.
# * **Anomaly Detection:** Identifying unusual patterns in data that might indicate problems or opportunities.
#
# **5. Internal Operations & Productivity:**
#
# * **Meeting Summarization:** Tools like Otter.ai are already doing this, but generative AI can create even more detailed and actionable summaries.
# * **Document Generation:**  Creating legal documents, contracts, and internal policies.
# * **Training Materials:** Generating training manuals, quizzes, and interactive learning modules.
#
#
# **Levels of Impact & Examples by Company Size:**
#
# * **Small Businesses:**  Can leverage AI for content creation (social media), basic customer support (chatbots), and streamlining simple tasks like email marketing.
# * **Mid-Sized Businesses:**  Can explore more complex applications like product development assistance, data analysis for marketing insights, and personalized customer experiences.
# * **Large Enterprises:**  Have the resources to integrate generative AI across numerous departments, potentially revolutionizing product development, R&D, and large-scale data analysis.
#
# **Important Considerations & Challenges:**
#
# * **Accuracy & Bias:** Generative AI models can sometimes produce inaccurate or biased outputs.  Human oversight is crucial.
# * **Copyright & Intellectual Property:**  The legal landscape surrounding AI-generated content is still evolving.
# * **Cost:**  Accessing some of the most powerful generative AI tools can be expensive.
# * **Hallucinations:**  AI can sometimes confidently present false information as fact.
#
# ---
#
# **Resources to Explore:**
#
# * **OpenAI:** [https://openai.com/](https://openai.com/)
# * **Jasper.ai:** [https://www.jasper.ai/](https://www.jasper.ai/)
# * **Copy.ai:** [https://www.copy.ai/](https://www.copy.ai/)
# * **DALL-E 2:** [https://openai.com/dall-e-2/](https://openai.com/dall-e-2/)
# * **Midjourney:** [https://www.midjourney.com/](https://www.midjourney.com/)
#
# To help me tailor the response even further, could you tell me:
#
# *   What industry are you most interested in (e.g., marketing, healthcare, finance)?
# *   Are there any specific business applications you’d like me to delve into in more detail (e.g., AI for generating marketing copy, AI for product design)?

# %% [markdown]
# # Introducing the ollama package
#
# And now we'll do the same thing, but using the elegant ollama python package instead of a direct HTTP call.
#
# Under the hood, it's making the same call as above to the ollama server running at localhost:11434

# %%
import ollama

response = ollama.chat(model=MODEL, messages=messages)
print(response['message']['content'])
# Out:
# Okay, let's break down the business applications of Generative AI – it’s a *huge* and rapidly expanding area. Here’s a categorized breakdown with examples:
#
# **1. Content Creation & Marketing:**
#
# * **Copywriting & Ad Generation:** This is arguably the most mature application right now. Tools like Jasper, Copy.ai, and Rytr use Generative AI to:
#     * **Generate Ad Copy:** Create variations of ad headlines, descriptions, and calls to action for various platforms (Google Ads, Facebook, etc.).
#     * **Write Blog Posts & Articles:** Produce initial drafts, outlines, or even entire articles on specific topics.
#     * **Create Social Media Content:** Generate captions, tweets, and even scripts for short videos.
#     * **Product Descriptions:** Quickly generate compelling descriptions for e-commerce websites.
# * **Visual Content Generation:**
#     * **Image Generation (Midjourney, DALL-E 2, Stable Diffusion):** Businesses can create unique images for marketing materials, websites, social media, and presentations, often just with text prompts. Imagine a clothing brand instantly generating images of its latest collection styled in various scenarios.
#     * **Video Generation (RunwayML, Pika Labs):**  These are emerging but promising.  Businesses can generate short videos from text prompts, significantly reducing the cost and time of video production.
# * **Personalized Content:** Generative AI can tailor content to individual customer preferences – creating personalized emails, product recommendations, and website experiences.
#
#
# **2. Product Development & Design:**
#
# * **Design Ideation & Prototyping:**  Tools like Khroma help designers explore color palettes, while others can generate initial product designs based on text descriptions.
# * **Code Generation:**  Tools like GitHub Copilot and Tabnine are *revolutionizing* software development. They suggest code snippets, complete functions, and even generate entire blocks of code based on comments or natural language instructions.
# * **3D Model Generation:**  Emerging tools are starting to generate 3D models from text prompts, useful for prototyping and design.
# * **Drug Discovery:** AI is being used to generate novel molecules with desired properties, accelerating the drug discovery process.
#
#
# **3. Customer Service & Support:**
#
# * **Chatbots & Virtual Assistants:** Generative AI powers more sophisticated chatbots that can understand and respond to customer queries in a natural, conversational way.  They can handle a wider range of questions and provide more personalized support.
# * **Automated Email Responses:**  Generate tailored email responses to common customer inquiries.
# * **Knowledge Base Creation:**  Automatically generate summaries and FAQs from existing documentation.
#
# **4. Operations & Administration:**
#
# * **Report Generation:**  AI can automatically generate reports based on data, summarizing key insights and trends.
# * **Meeting Summarization:** Tools like Otter.ai and Fireflies.ai (often utilizing Generative AI) can transcribe and summarize meetings, saving time and improving follow-up.
# * **Document Summarization:** Quickly condense lengthy documents, contracts, or research papers.
# * **Data Augmentation:** Generative AI can create synthetic data for training machine learning models, especially useful when real data is scarce or sensitive.
#
#
# **5.  Finance & Legal:**
#
# * **Contract Drafting & Review:** AI can assist in drafting and reviewing legal documents, identifying potential risks, and ensuring compliance.
# * **Financial Report Analysis:** Generate insights from financial data, identifying trends and anomalies.
# * **Fraud Detection:**  Analyze transactions and identify potentially fraudulent activity.
#
#
#
# **Key Technologies Powering These Applications:**
#
# * **Large Language Models (LLMs):**  Like GPT-3.5, GPT-4, Gemini, and Claude - these are the engines driving much of the conversational and text-based AI applications.
# * **Diffusion Models:** (Like Stable Diffusion) excel at image generation.
# * **Transformers:**  A neural network architecture that's particularly good at processing sequential data (like text and code).
#
# **Important Considerations & Challenges:**
#
# * **Accuracy & Hallucinations:** Generative AI models can sometimes produce inaccurate or nonsensical information (often called "hallucinations").  Human oversight is still crucial.
# * **Bias:**  AI models can reflect biases present in the data they were trained on.
# * **Copyright & Intellectual Property:**  The legal implications of using AI-generated content are still being sorted out.
# * **Cost:**  Accessing and using some of the most powerful Generative AI tools can be expensive.
#
# ---
#
# **Resources to Learn More:**
#
# * **OpenAI:** [https://openai.com/](https://openai.com/)
# * **Google AI:** [https://ai.google/](https://ai.google/)
# * **Midjourney:** [https://www.midjourney.com/](https://www.midjourney.com/)
# * **DALL-E 2:** [https://openai.com/dall-e-2/](https://openai.com/dall-e-2/)
# * **RunwayML:** [https://runwayml.com/](https://runwayml.com/)
#
#
# Would you like me to delve deeper into a specific area, such as:
#
# *   A particular industry application (e.g., marketing, healthcare)?
# *   A specific Generative AI tool?
# *   The ethical considerations surrounding AI-generated content?

# %% [markdown]
# ## Alternative approach - using OpenAI python library to connect to Ollama

# %%
# There's actually an alternative approach that some people might prefer
# You can use the OpenAI client python library to call Ollama:

from openai import OpenAI
ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

response = ollama_via_openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# Okay, let's break down the diverse business applications of Generative AI. It's a rapidly evolving field, and the possibilities are still being explored, but here's a categorized overview of how businesses are already using (and will likely continue to use) Generative AI:
#
# **1. Content Creation & Marketing:**
#
# * **Copywriting & Marketing Materials:**  This is arguably the most mature application.
#     * **Generating Ad Copy:** Tools like Jasper, Copy.ai, and others can create hundreds of variations of headlines, body copy, and calls to action for ads across platforms.
#     * **Blog Posts & Articles:** AI can draft entire blog posts, articles, and social media content based on a topic and desired tone.
#     * **Product Descriptions:** Generate compelling and informative descriptions for e-commerce sites.
#     * **Email Marketing:** Craft personalized email sequences, subject lines, and even entire newsletters.
# * **Visual Content:**
#     * **Image Generation:** DALL-E 2, Midjourney, Stable Diffusion – these tools can create original images from text prompts, used for marketing visuals, social media graphics, website illustrations, and even concept art.
#     * **Video Generation:** Tools like RunwayML and Pictory are emerging that can generate short videos from scripts, text, or images. (Still early stages, but incredibly promising).
#     * **Music Generation:** AI can compose music for background scores, jingles, and even entire tracks.
#
#
#
# **2. Product Development & Design:**
#
# * **Brainstorming & Concept Generation:**  AI can rapidly generate numerous design concepts, product ideas, and feature sets – accelerating the initial stages of innovation.
# * **Design Iteration:**  Feed an AI a basic design and have it generate variations, exploring different styles, colors, and layouts.
# * **3D Modeling:** Some AI tools are starting to generate 3D models from text descriptions, though this is still in development.
# * **Software Code Generation:**
#    * **Generating Code Snippets:**  Tools like GitHub Copilot and Tabnine use AI to suggest code completions, translate between programming languages, and even write entire functions based on natural language descriptions.
#    * **Debugging:** AI can help identify and fix errors in code, making development faster and more efficient.
#
# **3. Customer Service & Support:**
#
# * **Chatbots & Virtual Assistants:**  Generative AI takes chatbots to the next level, enabling more natural and engaging conversations.  They can handle complex inquiries, personalize responses, and even proactively offer assistance.
# * **Knowledge Base Generation:**  AI can extract information from existing documents to automatically create and update knowledge bases.
# * **Sentiment Analysis & Response Personalization:**  AI can analyze customer feedback to understand sentiment and tailor responses accordingly.
#
# **4. Data Analysis & Business Intelligence:**
#
# * **Data Summarization:** Quickly summarize large datasets into key insights.
# * **Report Generation:** Automate the creation of reports, freeing up analysts to focus on deeper analysis.
# * **Hypothesis Generation:** AI can suggest potential correlations and insights, prompting further investigation.
#
# **5. Operations & Administration:**
#
# * **Meeting Summaries & Action Items:** Tools are emerging that can transcribe, summarize, and extract action items from meetings.
# * **Document Creation & Editing:** Automate tasks like creating contracts, proposals, and other standard documents.
# * **Process Automation:**  AI can be integrated into business workflows to automate repetitive tasks across various departments.
#
#
#
# **Key Generative AI Models Driving These Applications:**
#
# * **GPT-3/GPT-4 (OpenAI):**  The powerhouse behind many text-based applications (chatbots, copywriting, code generation).
# * **DALL-E 2 & Midjourney:**  For image generation.
# * **Stable Diffusion:** Open-source image generation.
# * **LaMDA (Google):**  Powering Google’s conversational AI experiences.
# * **Claude (Anthropic):** Focuses on safety and reliability in conversational AI.
#
#
# **Important Considerations & Challenges:**
#
# * **Accuracy & Bias:** Generative AI models can sometimes produce inaccurate, misleading, or biased content.  Human oversight is crucial.
# * **Copyright & Intellectual Property:** Issues surrounding ownership of AI-generated content are still being worked out legally.
# * **Cost:** Some of the most powerful AI models can be expensive to use.
# * **Ethical Concerns:** Potential for misuse (deepfakes, misinformation) needs to be addressed.
#
# ---
#
# **Resources to Learn More:**
#
# * **OpenAI:** [https://openai.com/](https://openai.com/)
# * **Midjourney:** [https://www.midjourney.com/](https://www.midjourney.com/)
# * **DALL-E 2:** [https://openai.com/dall-e-2/](https://openai.com/dall-e-2/)
# * **GitHub Copilot:** [https://github.com/features/copilot](https://github.com/features/copilot)
#
#
#
# Would you like me to delve deeper into a specific application area (e.g., image generation, copywriting, or a particular industry use case)?

# %% [markdown]
# ## Are you confused about why that works?
#
# It seems strange, right? We just used OpenAI code to call Ollama?? What's going on?!
#
# Here's the scoop:
#
# The python class `OpenAI` is simply code written by OpenAI engineers that makes calls over the internet to an endpoint.
#
# When you call `openai.chat.completions.create()`, this python code just makes a web request to the following url: "https://api.openai.com/v1/chat/completions"
#
# Code like this is known as a "client library" - it's just wrapper code that runs on your machine to make web requests. The actual power of GPT is running on OpenAI's cloud behind this API, not on your computer!
#
# OpenAI was so popular, that lots of other AI providers provided identical web endpoints, so you could use the same approach.
#
# So Ollama has an endpoint running on your local box at http://localhost:11434/v1/chat/completions
# And in week 2 we'll discover that lots of other providers do this too, including Gemini and DeepSeek.
#
# And then the team at OpenAI had a great idea: they can extend their client library so you can specify a different 'base url', and use their library to call any compatible API.
#
# That's it!
#
# So when you say: `ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')`
# Then this will make the same endpoint calls, but to Ollama instead of OpenAI.

# %% [markdown]
# ## Also trying the amazing reasoning model DeepSeek
#
# Here we use the version of DeepSeek-reasoner that's been distilled to 1.5B.
# This is actually a 1.5B variant of Qwen that has been fine-tuned using synethic data generated by Deepseek R1.
#
# Other sizes of DeepSeek are [here](https://ollama.com/library/deepseek-r1) all the way up to the full 671B parameter version, which would use up 404GB of your drive and is far too large for most!

# %%
# !ollama pull deepseek-r1:1.5b

# %%
# This may take a few minutes to run! You should then see a fascinating "thinking" trace inside <think> tags, followed by some decent definitions

response = ollama_via_openai.chat.completions.create(
    model="deepseek-r1:1.5b",
    messages=[{"role": "user", "content": "Please give definitions of some core concepts behind LLMs: a neural network, attention and the transformer"}]
)

print(response.choices[0].message.content)

# %% [markdown]
# # NOW the exercise for you
#
# Take the code from day1 and incorporate it here, to build a website summarizer that uses Llama 3.2 running locally instead of OpenAI; use either of the above approaches.

# %%
# Step 1: Create your prompts

from openai import OpenAI
ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

system_prompt = "You are Bible Expert specialising in answering theological questions related to Bible"
user_prompt = """
    Why is Jesus the Messiah?
"""

# Step 2: Make the messages list

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
] # fill this in

# Step 3: Call OpenAI

response = ollama_via_openai.chat.completions.create(
    model = MODEL,
    messages = messages
)

# Step 4: print the result

print(response.choices[0].message.content)
# Out:
# Okay, let's delve into this profoundly important question – why Jesus is considered the Messiah. It’s a question that’s at the heart of Christian faith, and it’s rooted in a complex interplay of Old Testament prophecy and the unfolding of God’s plan. Here's a breakdown, structured to address the key reasons, and acknowledging that understanding this requires a layered approach:
#
# **1. The Old Testament Messianic Prophecies:**
#
# * **The Hebrew Bible's Expectation:** The Jewish people of Jesus’ time *already* had a deeply ingrained expectation of the Messiah. This expectation wasn't based on a single, clear prophecy, but rather a collection of prophecies, psalms, and writings that pointed to a future king, deliverer, and righteous leader who would restore Israel and establish God’s kingdom on earth.
# * **Key Prophecies Fulfilled by Jesus:** Christians argue that Jesus fulfills numerous Old Testament prophecies in ways that no other figure does. Let's look at some key ones:
#     * **Isaiah 7:14:** "Behold, a virgin shall conceive and bear a son, and shall call his name Immanuel.” – Christians believe this prophecy refers to Mary giving birth to Jesus, connecting him directly to the divine.
#     * **Isaiah 53:5:** “But he was wounded for our transgressions, he was crushed for our iniquities; and he bore our sins in his body upon the tree.” – This is arguably the most frequently cited messianic prophecy. It describes a suffering servant who will be unjustly punished and ultimately atone for the sins of humanity, aligning perfectly with Jesus' crucifixion.
#     * **Psalm 22:** This deeply evocative psalm, describing a figure suffering and abandoned, is seen by Christians as a prophetic depiction of Jesus’ crucifixion.
#     * **Deuteronomy 18:18-19:** This passage speaks of the Messiah as a prophet, priest, and king, a single figure who would embody these roles.  Jesus, as he lived and taught, demonstrated qualities of all three.
#     * **Micah 5:2:** “But for you shall be of David, who comes from Bethlehem, saying, ‘Surely, you shall house in the name of the Lord—the Counselor, the Mighty God, the Prince of Peace.’” – This prophecy points to a descendant of David who would usher in an era of peace and represent God's authority.
#
#
#
# **2. Jesus’ Life and Teachings:**
#
# * **Miracles:**  Throughout his ministry, Jesus performed miracles – healing the sick, casting out demons, controlling nature – which were seen as evidence of his divine power and fulfillment of God’s ancient promises.
# * **Moral Teachings:** Jesus’ teachings on love, forgiveness, compassion, and justice reflected a radical moral vision that challenged the social and religious norms of his time and pointed towards God’s will for humanity.
# * **Claim to Authority:** Jesus consistently claimed to be the Son of God and the Messiah, the one who had come to reveal God’s will and offer salvation to those who would believe in him.
#
# **3. The Argument from Fulfillment:**
#
# * **A Completed Prophecy:**  Christian theology argues that the messianic prophecies were *not* meant to be interpreted as open-ended predictions about any future leader, but rather as a specific blueprint for the Messiah. Jesus' life, death, and resurrection *fully* fulfilled these prophecies. This is often described as a concept of *fulfillment*.
#
#
#
# **Important Caveats & Considerations:**
#
# * **Jewish Understanding of the Messiah:** It's crucial to acknowledge that Judaism *also* has a concept of a Messiah.  However, their understanding differs significantly.  Jews traditionally anticipate a Messiah who will be a human king who will usher in an era of Jewish restoration and rule.  Christianity’s understanding of the Messiah is rooted in a belief that Jesus is both fully God and fully human, a concept distinct from the Jewish view.
# * **Interpretation:** The interpretation of Old Testament prophecies is complex and has been a subject of debate throughout Christian history.
#
#
#
# **In essence, Christians believe that Jesus is the Messiah because he is the one who, according to their interpretation of the Old Testament and the evidence of his life and teachings, perfectly embodies the hopes and expectations of God’s people for a savior and deliverer.**
#
# ---
#
# **Do you want me to delve deeper into a specific aspect of this topic, such as:**
#
# *   The different Jewish interpretations of the Messiah?
# *   A more detailed look at a particular prophecy?
# *   The theological concept of ‘covenant’ and how it relates to Jesus?
